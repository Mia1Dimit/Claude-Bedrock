# %%
import boto3

# %%
client = boto3.client("bedrock-runtime", region_name="eu-west-1")
model_id = "global.amazon.nova-2-lite-v1:0"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": [{"text": text}]}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": [{"text": text}]}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0):
    params = {
        "modelId": model_id,
        "messages": messages,
        "inferenceConfig": {
            "temperature": temperature,
        },
    }

    if system:
        params["system"] = [{"text": system}]

    response = client.converse(**params)

    return response["output"]["message"]["content"][0]["text"]

# %%
messages = []
add_user_message(messages, "Is coffee or tea better for breakfast?")
add_assistant_message(messages, "They are the same because")

chat(messages)
# Out:
# " of the ingredients they contain and the way that the body absorbs caffeine. One obvious difference between coffee and tea is the amount of caffeine each contains. Coffee contains more caffeine than tea, but this isn't really an advantage as caffeine can have many health risks when consumed in large amounts. When it comes to breakfast the most important thing to do is to make sure you have the right nutrients to give you energy. Tea and coffee don't have any nutritional value so they can't be considered healthy breakfast options. Most nutritionists suggest that a healthy breakfast should contain some kind of protein, carbohydrates, and fats in some form. This is the most important aspect of breakfast and determines whether it is healthy or not. So, neither tea nor coffee is better, but eating something that provides energy to your body like a balanced meal or a healthy smoothie would be a great idea for breakfast.\nSources: \nhttps://www.medicalnewstoday.com/articles/coffee-and-tea#coffee-vs.-tea\nhttps://www.medicalnewstoday.com/articles/best-breakfast-for-weight-loss#what-to-eat\n"
